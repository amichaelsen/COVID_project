# %%
import pandas as pd

# %%
#data source: https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-Jurisdi/unsk-b7fc
vaccine_data = pd.read_csv('../data/us_vaccination_data.csv')

# %%
vaccine_data.loc[:,'Date'] = pd.to_datetime(vaccine_data['Date'])
vaccine_data.head(2)
# Out:
#         Date  MMWR_week   Location  Distributed  Distributed_Janssen  \
# 0 2021-11-18         46  Wisconsin      9104875               401300
# 1 2021-11-18         46      Maine      2577840               140100
#
#    Distributed_Moderna  Distributed_Pfizer  Distributed_Unk_Manuf  \
# 0              3498440             5205135                      0
# 1              1045780             1391960                      0
#
#    Dist_Per_100K  Distributed_Per_100k_12Plus  ...  Additional_Doses_18Plus  \
# 0         156376                       182105  ...                 798557.0
# 1         191773                       217551  ...                 210467.0
#
#    Additional_Doses_18Plus_Vax_Pct  Additional_Doses_50Plus  \
# 0                             24.7                 631862.0
# 1                             23.2                 177348.0
#
#    Additional_Doses_50Plus_Vax_Pct  Additional_Doses_65Plus  \
# 0                             34.5                 453152.0
# 1                             33.2                 130614.0
#
#    Additional_Doses_65Plus_Vax_Pct  Additional_Doses_Moderna  \
# 0                             48.2                  288513.0
# 1                             47.6                   88826.0
#
#    Additional_Doses_Pfizer  Additional_Doses_Janssen  \
# 0                 503091.0                    7579.0
# 1                 118554.0                    3025.0
#
#    Additional_Doses_Unk_Manuf
# 0                        25.0
# 1                       177.0
#
# [2 rows x 69 columns]

# %%
vaccine_data.columns
# Out:
# Index(['Date', 'MMWR_week', 'Location', 'Distributed', 'Distributed_Janssen',
#        'Distributed_Moderna', 'Distributed_Pfizer', 'Distributed_Unk_Manuf',
#        'Dist_Per_100K', 'Distributed_Per_100k_12Plus',
#        'Distributed_Per_100k_18Plus', 'Distributed_Per_100k_65Plus',
#        'Administered', 'Administered_12Plus', 'Administered_18Plus',
#        'Administered_65Plus', 'Administered_Janssen', 'Administered_Moderna',
#        'Administered_Pfizer', 'Administered_Unk_Manuf', 'Admin_Per_100K',
#        'Admin_Per_100k_12Plus', 'Admin_Per_100k_18Plus',
#        'Admin_Per_100k_65Plus', 'Recip_Administered',
#        'Administered_Dose1_Recip', 'Administered_Dose1_Pop_Pct',
#        'Administered_Dose1_Recip_12Plus',
#        'Administered_Dose1_Recip_12PlusPop_Pct',
#        'Administered_Dose1_Recip_18Plus',
#        'Administered_Dose1_Recip_18PlusPop_Pct',
#        'Administered_Dose1_Recip_65Plus',
#        'Administered_Dose1_Recip_65PlusPop_Pct', 'Series_Complete_Yes',
#        'Series_Complete_Pop_Pct', 'Series_Complete_12Plus',
#        'Series_Complete_12PlusPop_Pct', 'Series_Complete_18Plus',
#        'Series_Complete_18PlusPop_Pct', 'Series_Complete_65Plus',
#        'Series_Complete_65PlusPop_Pct', 'Series_Complete_Janssen',
#        'Series_Complete_Moderna', 'Series_Complete_Pfizer',
#        'Series_Complete_Unk_Manuf', 'Series_Complete_Janssen_12Plus',
#        'Series_Complete_Moderna_12Plus', 'Series_Complete_Pfizer_12Plus',
#        'Series_Complete_Unk_Manuf_12Plus', 'Series_Complete_Janssen_18Plus',
#        'Series_Complete_Moderna_18Plus', 'Series_Complete_Pfizer_18Plus',
#        'Series_Complete_Unk_Manuf_18Plus', 'Series_Complete_Janssen_65Plus',
#        'Series_Complete_Moderna_65Plus', 'Series_Complete_Pfizer_65Plus',
#        'Series_Complete_Unk_Manuf_65Plus', 'Additional_Doses',
#        'Additional_Doses_Vax_Pct', 'Additional_Doses_18Plus',
#        'Additional_Doses_18Plus_Vax_Pct', 'Additional_Doses_50Plus',
#        'Additional_Doses_50Plus_Vax_Pct', 'Additional_Doses_65Plus',
#        'Additional_Doses_65Plus_Vax_Pct', 'Additional_Doses_Moderna',
#        'Additional_Doses_Pfizer', 'Additional_Doses_Janssen',
#        'Additional_Doses_Unk_Manuf'],
#       dtype='object')

# %% [markdown]
# Administered
# Total number of administered vaccines based on state __where administered__
#
# Administered_12Plus
# Total number of doses administered to people 12+ based on the jurisdiction __where recipient lives__

# %%
vaccine_data.head()
# Out:
#         Date  MMWR_week   Location  Distributed  Distributed_Janssen  \
# 0 2021-11-18         46  Wisconsin      9104875               401300
# 1 2021-11-18         46      Maine      2577840               140100
# 2 2021-11-18         46  Tennessee     10095640               454100
# 3 2021-11-18         46         MH        65910                11700
# 4 2021-11-18         46     Alaska      1253955                80000
#
#    Distributed_Moderna  Distributed_Pfizer  Distributed_Unk_Manuf  \
# 0              3498440             5205135                      0
# 1              1045780             1391960                      0
# 2              3965120             5676420                      0
# 3                47700                6510                      0
# 4               489760              684195                      0
#
#    Dist_Per_100K  Distributed_Per_100k_12Plus  ...  Additional_Doses_18Plus  \
# 0         156376                       182105  ...                 798557.0
# 1         191773                       217551  ...                 210467.0
# 2         147831                       173002  ...                 652279.0
# 3          84782                       114888  ...                    375.0
# 4         171412                       205946  ...                  89302.0
#
#    Additional_Doses_18Plus_Vax_Pct  Additional_Doses_50Plus  \
# 0                             24.7                 631862.0
# 1                             23.2                 177348.0
# 2                             20.5                 532037.0
# 3                              1.8                    143.0
# 4                             24.5                  62853.0
#
#    Additional_Doses_50Plus_Vax_Pct  Additional_Doses_65Plus  \
# 0                             34.5                 453152.0
# 1                             33.2                 130614.0
# 2                             29.4                 382737.0
# 3                              2.8                     37.0
# 4                             36.6                  37817.0
#
#    Additional_Doses_65Plus_Vax_Pct  Additional_Doses_Moderna  \
# 0                             48.2                  288513.0
# 1                             47.6                   88826.0
# 2                             41.2                  256631.0
# 3                              3.1                     371.0
# 4                             49.6                   37289.0
#
#    Additional_Doses_Pfizer  Additional_Doses_Janssen  \
# 0                 503091.0                    7579.0
# 1                 118554.0                    3025.0
# 2                 387859.0                    7387.0
# 3                      4.0                       0.0
# 4                  51443.0                     814.0
#
#    Additional_Doses_Unk_Manuf
# 0                        25.0
# 1                       177.0
# 2                      1465.0
# 3                         0.0
# 4                        11.0
#
# [5 rows x 69 columns]

# %%
vaccine_data['Location'].unique()
# Out:
# array(['Wisconsin', 'Maine', 'Tennessee', 'MH', 'Alaska',
#        'District of Columbia', 'South Carolina', 'US', 'Oklahoma',
#        'Arizona', 'DD2', 'VI', 'Iowa', 'MP', 'Rhode Island', 'Georgia',
#        'Utah', 'Idaho', 'Nebraska', 'North Dakota', 'VA2',
#        'New Hampshire', 'Virginia', 'PR', 'IH2', 'Hawaii', 'AS',
#        'Pennsylvania', 'Connecticut', 'Indiana', 'New Mexico', 'Texas',
#        'Wyoming', 'Montana', 'Maryland', 'RP', 'Delaware', 'New Jersey',
#        'Illinois', 'Arkansas', 'Michigan', 'Kansas', 'West Virginia',
#        'Washington', 'South Dakota', 'Oregon', 'Vermont', 'BP2',
#        'New York', 'Colorado', 'Nevada', 'Kentucky', 'Missouri',
#        'Louisiana', 'Massachusetts', 'Mississippi', 'North Carolina',
#        'Minnesota', 'FM', 'GU', 'Alabama', 'Florida', 'California',
#        'Ohio', 'LTC'], dtype=object)

# %%
# convert state codes to state names
# dict creds to: https://gist.github.com/rugbyprof/76575b470b6772ce8fa0c49e23931d97
states_codes_dict = {"AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas",
          "CA":"California","CO":"Colorado","CT":"Connecticut","DE":"Delaware",
          "FL":"Florida","GA":"Georgia","HI":"Hawaii","ID":"Idaho",
          "IL":"Illinois","IN":"Indiana","IA":"Iowa","KS":"Kansas",
          "KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland",
          "MA":"Massachusetts","MI":"Michigan","MN":"Minnesota","MS":"Mississippi",
          "MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada",
          "NH":"New Hampshire","NJ":"New Jersey","NM":"New Mexico","NY":"New York",
          "NC":"North Carolina","ND":"North Dakota","OH":"Ohio","OK":"Oklahoma",
          "OR":"Oregon","PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina",
          "SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah","VT":"Vermont",
          "VA":"Virginia","WA":"Washington","WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"}
states_codes_dict['DC'] = 'District of Columbia'

# %%
vaccine_data.replace({'Location':states_codes_dict}, inplace=True)

# %%
# restrict down to contiguous regions in the US
#vaccine_data['Location'].unique()
contiguous_US = ['Michigan','Wyoming','Maryland','Massachusetts','Rhode Island','Oregon',
                 'Pennsylvania','West Virginia','District of Columbia','Maine','Indiana',
                 'Nevada','Georgia','New Mexico','Colorado','Virginia','Kentucky','Minnesota',
                 'Arkansas','Connecticut','North Carolina','Montana','Oklahoma','Louisiana',
                 'Nebraska','Alabama','Florida','North Dakota','Delaware','Vermont','Idaho',
                 'Kansas','Wisconsin','New Jersey','Iowa','Missouri','New York','Utah',
                 'Washington','Arizona','Tennessee','Ohio','Texas','Mississippi','South Carolina',
                 'California','New Hampshire','South Dakota','Illinois']
cont_vaccine_data = vaccine_data[vaccine_data['Location'].isin(contiguous_US)]
cont_vaccine_data['Location'].nunique()
# Out:
# 49

# %%
ca_data = cont_vaccine_data[cont_vaccine_data['Location']=='California']

# %%
ca_data[['Date','Location','Administered', 'Administered_12Plus', 'Administered_18Plus', 'Administered_65Plus']].sort_values(by='Date')
# Out:
#             Date    Location  Administered  Administered_12Plus  \
# 22020 2020-12-14  California             0                    0
# 21912 2020-12-15  California             0                    0
# 21882 2020-12-16  California             4                    0
# 21832 2020-12-17  California           273                    0
# 21754 2020-12-18  California           273                    0
# ...          ...         ...           ...                  ...
# 275   2021-11-14  California      56602021             56282303
# 200   2021-11-15  California      57054577             56659451
# 163   2021-11-16  California      57134769             56725331
# 100   2021-11-17  California      57271043             56842025
# 62    2021-11-18  California      57552889             57094070
#
#        Administered_18Plus  Administered_65Plus
# 22020                    0                    0
# 21912                    0                    0
# 21882                    0                    0
# 21832                    0                    0
# 21754                    0                    0
# ...                    ...                  ...
# 275               52175690             12825098
# 200               52536231             12934684
# 163               52599116             12949977
# 100               52710246             12986301
# 62                52953591             13064588
#
# [340 rows x 6 columns]

# %%
ca_data['Administered_12_to_17'] = ca_data['Administered_12Plus'] - ca_data['Administered_18Plus']
ca_data['Administered_18_to_64'] = ca_data['Administered_18Plus'] - ca_data['Administered_65Plus']
# Out:
# /var/folders/8n/v409d_pd7m18zx23825fgzsc0000gn/T/ipykernel_63742/631359516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_data['Administered_12_to_17'] = ca_data['Administered_12Plus'] - ca_data['Administered_18Plus']
# /var/folders/8n/v409d_pd7m18zx23825fgzsc0000gn/T/ipykernel_63742/631359516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca_data['Administered_18_to_64'] = ca_data['Administered_18Plus'] - ca_data['Administered_65Plus']

# %%
ca_data[['Date','Location', 'Administered_12_to_17',
        'Administered_18_to_64', 'Administered_65Plus']].sort_values(by='Date')
# Out:
#             Date    Location  Administered_12_to_17  Administered_18_to_64  \
# 22020 2020-12-14  California                      0                      0
# 21912 2020-12-15  California                      0                      0
# 21882 2020-12-16  California                      0                      0
# 21832 2020-12-17  California                      0                      0
# 21754 2020-12-18  California                      0                      0
# ...          ...         ...                    ...                    ...
# 275   2021-11-14  California                4106613               39350592
# 200   2021-11-15  California                4123220               39601547
# 163   2021-11-16  California                4126215               39649139
# 100   2021-11-17  California                4131779               39723945
# 62    2021-11-18  California                4140479               39889003
#
#        Administered_65Plus
# 22020                    0
# 21912                    0
# 21882                    0
# 21832                    0
# 21754                    0
# ...                    ...
# 275               12825098
# 200               12934684
# 163               12949977
# 100               12986301
# 62                13064588
#
# [340 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# very inconsistent in when the data for smaller categories was reported, as seen by the jumps. 
sns.lineplot(data=ca_data, x='Date', y='Administered_12Plus', label="12+")
sns.lineplot(data=ca_data, x='Date', y='Administered', label="admin");
sns.lineplot(data=ca_data, x='Date', y='Administered_18Plus', label="18+");
sns.lineplot(data=ca_data, x='Date', y='Administered_65Plus', label="65+");
plt.legend();

# %%
temp_df = ca_data.copy()
temp_df['admin_minus_18plus'] = temp_df['Administered'] - temp_df['Administered_18Plus'] 
temp_df['admin_minus_65plus'] = temp_df['Administered'] - temp_df['Administered_65Plus']
temp_df['admin_minus_12plus'] = temp_df['Administered'] - temp_df['Administered_12Plus']
temp_df['recip_admin_minus_admin'] = temp_df['Recip_Administered'] - temp_df['Administered'] 
temp_df = temp_df[temp_df['Date'] <= pd.to_datetime('2021-05-01')]

# %%
# very inconsistent in when the data for smaller categories was reported, as seen by the jumps. 
sns.lineplot(data=temp_df, x='Date', y='Administered', label="admin");
#sns.lineplot(data=temp_df, x='Date', y='Administered_12Plus', label="12+");
#sns.lineplot(data=temp_df, x='Date', y='admin_minus_12plus', label="all-12+");

sns.lineplot(data=temp_df, x='Date', y='Administered_18Plus', label="18+");
sns.lineplot(data=temp_df, x='Date', y='admin_minus_18plus', label="all-18+");

sns.lineplot(data=temp_df, x='Date', y='Administered_65Plus', label="65+");
sns.lineplot(data=temp_df, x='Date', y='admin_minus_65plus', label="all-65+");

plt.legend();

# %%
sns.lineplot(data=temp_df, x='Date', y='Recip_Administered');
sns.lineplot(data=temp_df, x='Date', y='Administered');

# %%
sns.lineplot(data=temp_df, x='Date', y='recip_admin_minus_admin');
sns.lineplot(data=temp_df, x='Date', y='Recip_Administered');
sns.lineplot(data=temp_df, x='Date', y='Administered');
# could fill in 'administered' values for the 0's in recip_admin as a backfilling measure

# %%
ca_data[['Date','Location','Administered', 'Administered_12Plus', 'Administered_18Plus', 'Administered_65Plus']].sort_values(by='Date')
# Out:
#             Date    Location  Admin - Admin12Plus  Administered  \
# 22020 2020-12-14  California                    0             0
# 21912 2020-12-15  California                    0             0
# 21882 2020-12-16  California                    4             4
# 21832 2020-12-17  California                  273           273
# 21754 2020-12-18  California                  273           273
# ...          ...         ...                  ...           ...
# 275   2021-11-14  California               319718      56602021
# 200   2021-11-15  California               395126      57054577
# 163   2021-11-16  California               409438      57134769
# 100   2021-11-17  California               429018      57271043
# 62    2021-11-18  California               458819      57552889
#
#        Administered_12Plus  Administered_18Plus  Administered_65Plus
# 22020                    0                    0                    0
# 21912                    0                    0                    0
# 21882                    0                    0                    0
# 21832                    0                    0                    0
# 21754                    0                    0                    0
# ...                    ...                  ...                  ...
# 275               56282303             52175690             12825098
# 200               56659451             52536231             12934684
# 163               56725331             52599116             12949977
# 100               56842025             52710246             12986301
# 62                57094070             52953591             13064588
#
# [340 rows x 7 columns]

# %%
cont_vaccine_data['Administered_18Plus'] - cont_vaccine_data['Administered_65Plus']# + cont_vaccine_data['Administered_12Plus']
# Out:
# 0        4958089
# 1        1310196
# 2        5118401
# 5         864927
# 6        3710971
#           ...
# 22025          0
# 22026          0
# 22030          0
# 22032          0
# 22033          0
# Length: 16660, dtype: int64

# %%
cont_vaccine_data['Administered'] - cont_vaccine_data['Administered_18Plus']
# Out:
# 0        504660
# 1        133199
# 2        409717
# 5         47350
# 6        338788
#           ...
# 22025         0
# 22026         0
# 22030         0
# 22032         0
# 22033         0
# Length: 16660, dtype: int64
