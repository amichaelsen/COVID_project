# %%
# pandas and numpy for working with data
import pandas as pd 
import numpy as np

# seaborn and matplotlib for visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load in the data frames 
deaths_by_cond = pd.read_csv("../data/cdc_death_counts_by_conditions.csv")

# %%
deaths_by_cond.head(10)
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 1  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 2  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 3  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 4  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 5  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 6  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 7  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 8  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
# 9  03/28/2021  01/01/2020  03/27/2021  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes   Age Group  \
# ...

# %%
deaths_by_cond.columns
# Out:
# Index(['Data As Of', 'Start Date', 'End Date', 'Group', 'Year', 'Month',
#        'State', 'Condition Group', 'Condition', 'ICD10_codes', 'Age Group',
#        'COVID-19 Deaths', 'Number of Mentions', 'Flag'],
#       dtype='object')

# %%
deaths_by_cond['Condition Group'].unique()
# Out:
# array(['Respiratory diseases', 'Circulatory diseases', 'Sepsis',
#        'Malignant neoplasms', 'Diabetes', 'Obesity', 'Alzheimer disease',
#        'Vascular and unspecified dementia', 'Renal failure',
#        'Intentional and unintentional injury, poisoning, and other adverse events',
#        'All other conditions and causes (residual)', 'COVID-19'],
#       dtype=object)

# %%
print(deaths_by_cond['Age Group'].unique())
print(deaths_by_cond['Flag'].unique())
print(deaths_by_cond['State'].unique())
print(len(deaths_by_cond['State'].unique()))
print(deaths_by_cond['Group'].unique())
print(deaths_by_cond['Year'].unique())
print(deaths_by_cond['Month'].unique())
print(deaths_by_cond['Condition Group'].unique())
# Out:
# ['0-24' '25-34' '35-44' '45-54' '55-64' '65-74' '75-84' '85+' 'Not stated'
#  'All Ages']
# [nan
#  'One or more data cells have counts between 1-9 and have been suppressed in accordance with NCHS confidentiality standards.']
# ['United States' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'District of Columbia' 'Florida'
#  'Georgia' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada'
#  'New Hampshire' 'New Jersey' 'New Mexico' 'New York' 'New York City'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming'
#  'Puerto Rico']
# 54
# ['By Total' 'By Year' 'By Month']
# [  nan 2020. 2021.]
# ...

# %%
deaths_by_cond[(deaths_by_cond['Condition Group']=='Respiratory diseases') &
              (deaths_by_cond['Group']=='By Total') & 
              (deaths_by_cond['State'] == "United States") & 
              (deaths_by_cond['Age Group'] == 'All Ages')]
# Out:
#     Data As Of Start Date   End Date     Group  Year  Month          State  \
# 9   03/28/2021 2020-01-01 2021-03-27  By Total   NaN    NaN  United States
# 19  03/28/2021 2020-01-01 2021-03-27  By Total   NaN    NaN  United States
# 29  03/28/2021 2020-01-01 2021-03-27  By Total   NaN    NaN  United States
# 39  03/28/2021 2020-01-01 2021-03-27  By Total   NaN    NaN  United States
# 49  03/28/2021 2020-01-01 2021-03-27  By Total   NaN    NaN  United States
# 59  03/28/2021 2020-01-01 2021-03-27  By Total   NaN    NaN  United States
#
#          Condition Group                                 Condition  \
# 9   Respiratory diseases                   Influenza and pneumonia
# 19  Respiratory diseases        Chronic lower respiratory diseases
# 29  Respiratory diseases       Adult respiratory distress syndrome
# 39  Respiratory diseases                       Respiratory failure
# 49  Respiratory diseases                        Respiratory arrest
# ...

# %%
deaths_by_cond[['Condition Group','Condition']].groupby('Condition Group').nunique().sum()
# Out:
# Condition    23
# dtype: int64

# %%
group_opts = len(deaths_by_cond['Group'].unique()) 
age_group_opts = len(deaths_by_cond['Age Group'].unique()) 
cond_group_opts = len(deaths_by_cond['Condition Group'].unique()) 
state_opts = len(deaths_by_cond['State'].unique())
year_opts = len(deaths_by_cond['Year'].unique())
month_opts = len(deaths_by_cond['Month'].unique())

date_opts = 1 + (year_opts - 1) + (year_opts - 1) * (month_opts - 1) # by_total, by_year, by_month options 

age_group_opts * 23 * state_opts * date_opts
# Out:
# 335340

# %%
deaths_by_cond['Start Date'] = pd.to_datetime(deaths_by_cond['Start Date'])
deaths_by_cond['End Date'] = pd.to_datetime(deaths_by_cond['End Date'])

# %%
deaths_by_cond['Start Date']
# Out:
# 0        2020-01-01
# 1        2020-01-01
# 2        2020-01-01
# 3        2020-01-01
# 4        2020-01-01
#             ...
# 223555   2020-11-01
# 223556   2020-12-01
# 223557   2021-01-01
# 223558   2021-02-01
# 223559   2021-03-01
# Name: Start Date, Length: 223560, dtype: datetime64[ns]

# %%
deaths_by_cond[['Start Date','End Date','Data As Of']].sort_values(by='Start Date').groupby(['Start Date','End Date']).count()
# Out:
#                        Data As Of
# Start Date End Date
# 2020-01-01 2020-01-31       12420
#            2020-12-31       12420
#            2021-03-27       12420
# 2020-02-01 2020-02-29       12420
# 2020-03-01 2020-03-31       12420
# 2020-04-01 2020-04-30       12420
# 2020-05-01 2020-05-31       12420
# 2020-06-01 2020-06-30       12420
# 2020-07-01 2020-07-31       12420
# 2020-08-01 2020-08-28       12420
# 2020-09-01 2020-09-30       12420
# 2020-10-01 2020-10-31       12420
# 2020-11-01 2020-11-30       12420
# 2020-12-01 2020-12-31       12420
# 2021-01-01 2021-01-31       12420
#            2021-03-27       12420
# 2021-02-01 2021-02-28       12420
# 2021-03-01 2021-03-27       12420

# %%
#only one value, all data as of the same date 
deaths_by_cond['Data As Of'].unique()
# Out:
# array(['03/28/2021'], dtype=object)
